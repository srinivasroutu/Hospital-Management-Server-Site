# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
test_dir = r"C:\Users\srini\OneDrive\Documents\6TH SEM\DSAI\project\Alzheimer_s Dataset\test"
train_dir = r"C:\Users\srini\OneDrive\Documents\6TH SEM\DSAI\project\Alzheimer_s Dataset\train"

# %%
data = []

# %%
for dirtrain in os.listdir(train_dir):
    print(dirtrain)
    for tr in os.listdir(os.path.join(train_dir, dirtrain)):
        img = cv2.imread(os.path.join(train_dir, dirtrain, tr))
        img = cv2.resize(img, (32, 32))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = img.reshape(32, 32, 1)
        data.append([img, dirtrain])
# Out:
# MildDemented
# ModerateDemented
# NonDemented

# %%
for dirtest in os.listdir(test_dir):
    print(dirtest)
    for ts in os.listdir(os.path.join(test_dir, dirtest)):
        img = cv2.imread(os.path.join(test_dir, dirtest, ts))
        img = cv2.resize(img, (32, 32))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = img.reshape(32, 32, 1)
        data.append([img, dirtest])
# Out:
# MildDemented
# ModerateDemented
# NonDemented
# VeryMildDemented

# %%
# Shuffle data
random.seed(20)
random.shuffle(data)

# Split data into features and labels
x, y = zip(*data)
x = np.array(x)
y = np.array(y)
y = y.reshape(y.shape[0], 1)

# One-hot encode labels
enc = OneHotEncoder(handle_unknown='ignore').fit(y)
y = enc.transform(y).toarray()

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1, test_size=0.2)

# Model setup
model = Sequential([
    Conv2D(64, (4, 4), padding='same', activation='relu', input_shape=(32, 32, 1)),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Conv2D(128, (2, 2), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Conv2D(256, (2, 2), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')
])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Shuffle data
# ----> 2 random.seed(20)
#       3 random.shuffle(data)
#       5 # Split data into features and labels
#
# NameError: name 'random' is not defined

# %%
import random

# %%
# Shuffle data
random.seed(20)
random.shuffle(data)

# Split data into features and labels
x, y = zip(*data)
x = np.array(x)
y = np.array(y)
y = y.reshape(y.shape[0], 1)

# One-hot encode labels
enc = OneHotEncoder(handle_unknown='ignore').fit(y)
y = enc.transform(y).toarray()

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1, test_size=0.2)

# Model setup
model = Sequential([
    Conv2D(64, (4, 4), padding='same', activation='relu', input_shape=(32, 32, 1)),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Conv2D(128, (2, 2), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Conv2D(256, (2, 2), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=(2, 2)),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1088
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         65664
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         131328
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 452,932
# Trainable params: 452,932
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Model training
hist = model.fit(x_train, y_train, epochs=200, validation_split=0.2, batch_size=64, verbose=1, shuffle=True)
# Out:
# Epoch 1/200
# 64/64 [==============================] - 14s 187ms/step - loss: 2.0780 - accuracy: 0.4517 - val_loss: 1.1364 - val_accuracy: 0.5176
# Epoch 2/200
# 64/64 [==============================] - 12s 183ms/step - loss: 1.0516 - accuracy: 0.4844 - val_loss: 1.0920 - val_accuracy: 0.5176
# Epoch 3/200
# 64/64 [==============================] - 12s 185ms/step - loss: 1.0170 - accuracy: 0.4934 - val_loss: 0.9631 - val_accuracy: 0.5527
# Epoch 4/200
# 64/64 [==============================] - 14s 211ms/step - loss: 0.9886 - accuracy: 0.5061 - val_loss: 0.9326 - val_accuracy: 0.5283
# Epoch 5/200
# 64/64 [==============================] - 14s 219ms/step - loss: 0.9863 - accuracy: 0.5049 - val_loss: 0.9594 - val_accuracy: 0.5850
# Epoch 6/200
# 64/64 [==============================] - 13s 201ms/step - loss: 0.9751 - accuracy: 0.5186 - val_loss: 0.9509 - val_accuracy: 0.5869
# Epoch 7/200
# 64/64 [==============================] - 13s 199ms/step - loss: 0.9835 - accuracy: 0.4998 - val_loss: 0.9387 - val_accuracy: 0.5947
# Epoch 8/200
# 64/64 [==============================] - 14s 214ms/step - loss: 0.9427 - accuracy: 0.5400 - val_loss: 0.8893 - val_accuracy: 0.5791
# Epoch 9/200
# 64/64 [==============================] - 13s 206ms/step - loss: 0.9553 - accuracy: 0.5344 - val_loss: 0.9019 - val_accuracy: 0.5908
# Epoch 10/200
# 64/64 [==============================] - 13s 201ms/step - loss: 0.9384 - accuracy: 0.5498 - val_loss: 0.8924 - val_accuracy: 0.5957
# Epoch 11/200
# 64/64 [==============================] - 13s 204ms/step - loss: 0.9371 - accuracy: 0.5427 - val_loss: 0.8915 - val_accuracy: 0.5840
# Epoch 12/200
# 64/64 [==============================] - 13s 202ms/step - loss: 0.9255 - accuracy: 0.5479 - val_loss: 0.9008 - val_accuracy: 0.5781
# Epoch 13/200
# 64/64 [==============================] - 13s 203ms/step - loss: 0.9281 - accuracy: 0.5432 - val_loss: 0.9452 - val_accuracy: 0.5566
# Epoch 14/200
# 64/64 [==============================] - 14s 212ms/step - loss: 0.9254 - accuracy: 0.5513 - val_loss: 0.8597 - val_accuracy: 0.5869
# Epoch 15/200
# 64/64 [==============================] - 13s 204ms/step - loss: 0.9200 - accuracy: 0.5566 - val_loss: 0.8482 - val_accuracy: 0.5918
# Epoch 16/200
# 64/64 [==============================] - 13s 205ms/step - loss: 0
# Epoch 189/200
# 64/64 [==============================] - 13s 207ms/step - loss: 0.1152 - accuracy: 0.9639 - val_loss: 0.1508 - val_accuracy: 0.9463
# Epoch 190/200
# 64/64 [==============================] - 14s 214ms/step - loss: 0.0872 - accuracy: 0.9690 - val_loss: 0.1627 - val_accuracy: 0.9482
# Epoch 191/200
# 64/64 [==============================] - 13s 204ms/step - loss: 0.0745 - accuracy: 0.9719 - val_loss: 0.1578 - val_accuracy: 0.9521
# Epoch 192/200
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0931 - accuracy: 0.9695 - val_loss: 0.1731 - val_accuracy: 0.9434
# Epoch 193/200
# 64/64 [==============================] - 13s 199ms/step - loss: 0.1087 - accuracy: 0.9595 - val_loss: 0.1810 - val_accuracy: 0.9395
# Epoch 194/200
# 64/64 [==============================] - 13s 200ms/step - loss: 0.1096 - accuracy: 0.9595 - val_loss: 0.1583 - val_accuracy: 0.9482
# Epoch 195/200
# 64/64 [==============================] - 13s 202ms/step - loss: 0.1076 - accuracy: 0.9641 - val_loss: 0.1680 - val_accuracy: 0.9453
# Epoch 196/200
# 64/64 [==============================] - 13s 201ms/step - loss: 0.1017 - accuracy: 0.9600 - val_loss: 0.1465 - val_accuracy: 0.9512
# Epoch 197/200
# 64/64 [==============================] - 13s 200ms/step - loss: 0.1076 - accuracy: 0.9651 - val_loss: 0.1830 - val_accuracy: 0.9473
# Epoch 198/200
# 64/64 [==============================] - 13s 201ms/step - loss: 0.0966 - accuracy: 0.9685 - val_loss: 0.1863 - val_accuracy: 0.9395
# Epoch 199/200
# 64/64 [==============================] - 14s 215ms/step - loss: 0.1108 - accuracy: 0.9644 - val_loss: 0.1792 - val_accuracy: 0.9453
# Epoch 200/200
# 64/64 [==============================] - 14s 226ms/step - loss: 0.0906 - accuracy: 0.9705 - val_loss: 0.1518 - val_accuracy: 0.9502

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
axes[0].plot(hist.history['loss'], color='teal', label='Training Loss')
axes[0].plot(hist.history['val_loss'], color='orange', label='Validation Loss')
axes[0].set_title('Loss')
axes[0].legend()

axes[1].plot(hist.history['accuracy'], color='teal', label='Training Accuracy')
axes[1].plot(hist.history['val_accuracy'], color='orange', label='Validation Accuracy')
axes[1].set_title('Accuracy')
axes[1].legend()

plt.show()

# %%
loss_and_metrics = model.evaluate(x_test, y_test, verbose=2)
print(f'Test Loss: {loss_and_metrics[0]}')
print(f'Test Accuracy: {loss_and_metrics[1]}')
# Out:
# 40/40 - 1s - loss: 0.1285 - accuracy: 0.9617 - 1s/epoch - 31ms/step
# Test Loss: 0.12852630019187927
# Test Accuracy: 0.961718738079071

# %%
y_pred = model.predict(x_test).argmax(axis=1)
confusion_matrix = metrics.confusion_matrix(np.argmax(y_test, axis=1), y_pred)
confusion_df = pd.DataFrame(confusion_matrix, columns=['0', '1', '2', '3'], index=['0', '1', '2', '3'])
print(confusion_df)
# Out:
# 40/40 [==============================] - 1s 26ms/step
#      0   1    2    3
# 0  167   0    5    6
# 1    0  13    0    0
# 2    2   0  645   10
# 3    2   0   24  406

# %%
model.save("alzheimer_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.save("alzheimer_model.h5")
#
# NameError: name 'model' is not defined
